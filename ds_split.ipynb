# %%
import pandas

# %%
df = pandas.read_csv("2024c\data\Wimbledon_featured_matches.csv")

# %%
matchid:list = list(set(df['match_id'].tolist()))
matchid.sort()

# %%
splits = []
# cur_df = df
pre = 0
for id in matchid:
    # try:
        result = df.loc[df['match_id'] == id].index[-1]
        # print(result)
        df1 = df.iloc[pre:result+1]
        # df2 = df.iloc[result+1:]
        # print(df1['match_id'].tolist()[-1], df2['match_id'].tolist()[0])
        splits.append(df1)
        pre = result+1

        # cur_df = df2
    # except:
    #     splits.append(cur_df)
    #     break

# %%
splits[-1].head()
# Out:
#                  match_id         player1         player2 elapsed_time  \
# 6950  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     00:00:00
# 6951  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     00:00:25
# 6952  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     00:01:19
# 6953  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     00:02:17
# 6954  2023-wimbledon-1701  Carlos Alcaraz  Novak Djokovic     00:03:02
#
#       set_no  game_no  point_no  p1_sets  p2_sets  p1_games  ...  \
# 6950       1        1         1        0        0         0  ...
# 6951       1        1         2        0        0         0  ...
# 6952       1        1         3        0        0         0  ...
# 6953       1        1         4        0        0         0  ...
# 6954       1        1         5        0        0         0  ...
#
#       p2_break_pt_won p1_break_pt_missed p2_break_pt_missed  p1_distance_run  \
# ...

# %%
output_dir = "./2024c/processed_data/origin/"
for i in splits:
    fn = i['match_id'].tolist()[0]
    i.to_csv(output_dir+fn)
